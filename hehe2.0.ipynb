# %%
import psycopg2
import pandas
pd = pandas

# %%
pgconn = psycopg2.connect(
    host= 'localhost',
    user = 'dev_test1',
    password = 'ayan',
    database = 'testing')

# %%
pgcursor = pgconn.cursor()

# %%
print(pgcursor)
# Out:
# <cursor object at 0x7f74be5fa4d0; closed: 0>

# %%
print(pgcursor.execute('select * from public."max_dates"'))
# Out:
# None

# %%
result = pgcursor.fetchall()

# %%
print(result)
# Out:
# []

# %%
df = pd.read_json ('5th.json_error',dtype={"size_of_file":list},lines=True)

# %%
df = pd.read_json ('6th.json',lines=True)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://dev_test1:ayan@localhost/testing')

# %%
print(engine)
# Out:
# Engine(postgresql+psycopg2://dev_test1:***@localhost/testing)

# %%
engine
# Out:
# Engine(postgresql+psycopg2://dev_test1:***@localhost/testing)

# %%
df
# Out:
#                                          size_of_file  create_time_stamp  \
# 0   [33204, 2886326, 2051, 1, 1000, 1000, 23, 1672...       1.672443e+09
# 1   [33204, 2886328, 2051, 1, 1000, 1000, 92, 1672...       1.672443e+09
# 2   [33204, 2886331, 2051, 1, 1000, 1000, 1536, 16...       1.672443e+09
# 3   [33204, 2886304, 2051, 1, 1000, 1000, 73, 1672...       1.672443e+09
# 4   [33060, 2886345, 2051, 1, 1000, 1000, 12409, 1...       1.672443e+09
# ..                                                ...                ...
# 67  [33277, 2886320, 2051, 1, 1000, 1000, 189, 167...       1.672443e+09
# 68  [33277, 2886321, 2051, 1, 1000, 1000, 478, 167...       1.672443e+09
# 69  [33277, 2886322, 2051, 1, 1000, 1000, 1643, 16...       1.672443e+09
# 70  [33204, 2886305, 2051, 1, 1000, 1000, 10020, 1...       1.672361e+09
# 71  [33204, 1715848, 2051, 1, 1000, 1000, 12149, 1...       1.672361e+09
#
#                                              abs_path  \
# ...

# %%
df.to_sql('file_inventory', engine, if_exists = 'append', index=False)
# Out:
# 72
